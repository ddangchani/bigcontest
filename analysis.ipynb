# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# for korean plotting
plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

# Pandas option
pd.set_option('display.max_columns', None)

# %%
# data load
df = pd.read_csv('df_transformed.csv')
df = df.drop(['상권타입_골목상권','아파트_평균_시가'], axis=1)
# df['아파트_단지수'] = df['아파트_단지수'].fillna(0)
df.shape
# Out:
# (1460, 33)

# %%
# Ordered Categorical Variable
cols_crime = ['살인', '강도', '강간', '절도', '폭력', '방화', '마약', '약취', '도박', '전체범죄']

t = pd.CategoricalDtype(categories=[1,2,3,4,5], ordered=True)
df[cols_crime] = df[cols_crime].astype(t)

# %% [markdown]
# ## Linear Models - Price as Y
# with `Statsmodels` package

# %%
# Endog, Exog, add Constatnt
X = df.drop(['평균매매가','평균조절가'], axis=1)
X = sm.add_constant(X, prepend=True)
y = df['평균매매가']
X.shape
# Out:
# (1460, 32)

# %% [markdown]
# ### OLS

# %%
# Model
model = sm.OLS(endog=y, exog=X, missing='drop')
# Result
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  평균매매가   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                  0.151
# Method:                 Least Squares   F-statistic:                     8.418
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):           3.85e-34
# Time:                        15:29:09   Log-Likelihood:                -1688.6
# No. Observations:                1294   AIC:                             3441.
# Df Residuals:                    1262   BIC:                             3606.
# Df Model:                          31
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.2065      0.131      1.579      0.115      -0.050       0.463
# Bus             -0.1105      0.034     -3.277      0.001      -0.177      -0.044
# Subway           0.0585      0.030      1.952      0.051      -0.000       0.117
# 유흥업소             0.0084      0.029      0.295      0.768      -0.048       0.064
# 살인               0.0500      0.019      2.597      0.010       0.012       0.088
# 강도              -0.0574      0.019     -3.002      0.003      -0.095      -0.020
# 강간               0.0259      0.038      0.674      0.500      -0.049       0.101
# 절도               0.0795      0.048      1.660      0.097      -0.014       0.173
# 폭력              -0.0039      0.051     -0.077      0.938      -0.103       0.095
# 방화              -0.0528      0.020     -2.653      0.008      -0.092      -0.014
# 마약               0.0224      0.021      1.050      0.294      -0.019       0.064
# 약취               0.0083      0.017      0.504      0.615      -0.024       0.041
# 도박               0.0069      0.019      0.362      0.717      -0.030       0.044
# 전체범죄            -0.0984      0.078     -1.256      0.209      -0.252       0.055
# 112신고            0.0681      0.029      2.382      0.017       0.012       0.124
# 총_생활인구           0.1552      0.047      3.286      0.001       0.063       0.248
# 아파트_단지수          0.0004      0.001      0.772      0.440      -0.001       0.001
# 매출액           2.002e-13   2.18e-13      0.919      0.358   -2.27e-13    6.28e-13
# 매출건수         -8.581e-09   1.17e-08     -0.731      0.465   -3.16e-08    1.44e-08
# 생활인구_야간비율       -0.2800      0.056     -4.995      0.000      -0.390      -0.170
# 생활인구_심야비율       -0.0580      0.052     -1.110      0.267      -0.161       0.045
# 생활인구_여성비율       -0.0016      0.033     -0.048      0.961      -0.066       0.063
# 상권타입_관광특구        0.5842      0.490      1.192      0.233      -0.377       1.546
# 상권타입_발달상권        0.2740      0.096      2.854      0.004       0.086       0.462
# 상권타입_전통시장       -0.0203      0.088     -0.231      0.817      -0.193       0.152
# 개업율_요식업         -0.8640      0.214     -4.031      0.000      -1.284      -0.443
# 폐업율_요식업          0.4923      0.257      1.912      0.056      -0.013       0.997
# 프랜차이즈비율_요식업      0.0386      0.043      0.902      0.367      -0.045       0.123
# 개업율_비요식업        -0.2559      0.591     -0.433      0.665      -1.415       0.903
# 폐업율_비요식업        -0.0905      0.748     -0.121      0.904      -1.557       1.376
# 프랜차이즈비율_비요식업    -0.0910      0.202     -0.450      0.653      -0.488       0.306
# 요식업비율           -0.3417      0.295     -1.156      0.248      -0.921       0.238
# ==============================================================================
# Omnibus:                       16.856   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.063
# Skew:                           0.067   Prob(JB):                     1.33e-06
# Kurtosis:                       3.696   Cond. No.                     5.78e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.78e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame({'variable' : col_i, 'VIF' : variance_inflation_factor(model.exog, i)} for i, col_i in enumerate(model.exog_names) if col_i != 'const')
vif[vif.VIF>4] # 강간, 절도, 폭력
# Out:
#    variable        VIF
# 5        강간   5.142793
# 6        절도   7.987656
# 7        폭력   8.835504
# 12     전체범죄  20.529326

# %%
# corr check
df[cols_crime].astype('float').corr('kendall')
# Out:
#             살인        강도        강간        절도        폭력        방화        마약  \
# 살인    1.000000  0.199048  0.302555  0.322558  0.341815  0.171913  0.276643
# 강도    0.199048  1.000000  0.319635  0.383788  0.396874  0.221154  0.257839
# 강간    0.302555  0.319635  1.000000  0.752168  0.717243  0.304560  0.465576
# 절도    0.322558  0.383788  0.752168  1.000000  0.724734  0.367022  0.383176
# 폭력    0.341815  0.396874  0.717243  0.724734  1.000000  0.370680  0.427230
# 방화    0.171913  0.221154  0.304560  0.367022  0.370680  1.000000  0.157211
# 마약    0.276643  0.257839  0.465576  0.383176  0.427230  0.157211  1.000000
# 약취    0.104177  0.109875  0.174696  0.141062  0.186848  0.129517  0.196359
# 도박    0.208194  0.180065  0.287585  0.329305  0.380518  0.194057  0.245590
# 전체범죄  0.332990  0.398743  0.795436  0.853410  0.873011  0.371183  0.440062
#
#             약취        도박      전체범죄
# 살인    0.104177  0.208194  0.332990
# 강도    0.109875  0.180065  0.398743
# 강간    0.174696  0.287585  0.795436
# 절도    0.141062  0.329305  0.853410
# 폭력    0.186848  0.380518  0.873011
# 방화    0.129517  0.194057  0.371183
# 마약    0.196359  0.245590  0.440062
# 약취    1.000000  0.143601  0.192190
# 도박    0.143601  1.000000  0.389317
# 전체범죄  0.192190  0.389317  1.000000

# %%
X_new = X.drop(['절도','전체범죄'],axis=1)
# Model
model_new = sm.OLS(endog=y, exog=X_new, missing='drop')
# Result
res = model_new.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  평균매매가   R-squared:                       0.210
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     11.17
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):           2.17e-46
# Time:                        15:20:03   Log-Likelihood:                -1657.9
# No. Observations:                1294   AIC:                             3378.
# Df Residuals:                    1263   BIC:                             3538.
# Df Model:                          30
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -0.1778      0.137     -1.302      0.193      -0.446       0.090
# Bus             -0.0810      0.033     -2.457      0.014      -0.146      -0.016
# Subway           0.0712      0.029      2.438      0.015       0.014       0.129
# 유흥업소             0.0220      0.028      0.789      0.430      -0.033       0.077
# 살인               0.0604      0.019      3.231      0.001       0.024       0.097
# 강도              -0.0473      0.019     -2.554      0.011      -0.084      -0.011
# 강간               0.0325      0.031      1.054      0.292      -0.028       0.093
# 폭력              -0.0306      0.033     -0.936      0.349      -0.095       0.033
# 방화              -0.0462      0.019     -2.391      0.017      -0.084      -0.008
# 마약               0.0099      0.021      0.479      0.632      -0.031       0.050
# 약취              -0.0004      0.016     -0.024      0.981      -0.032       0.031
# 도박               0.0112      0.018      0.617      0.537      -0.024       0.047
# 112신고            0.0452      0.028      1.623      0.105      -0.009       0.100
# 총_생활인구           0.1760      0.046      3.819      0.000       0.086       0.266
# 아파트_단지수          0.0003      0.001      0.495      0.620      -0.001       0.001
# 아파트_평균_시가     1.332e-09   1.66e-10      8.013      0.000    1.01e-09    1.66e-09
# 매출액           1.833e-13   2.12e-13      0.863      0.388   -2.33e-13       6e-13
# 매출건수         -1.039e-08   1.14e-08     -0.908      0.364   -3.28e-08    1.21e-08
# 생활인구_야간비율       -0.1811      0.056     -3.229      0.001      -0.291      -0.071
# 생활인구_심야비율       -0.0542      0.051     -1.063      0.288      -0.154       0.046
# 생활인구_여성비율       -0.0265      0.032     -0.827      0.409      -0.089       0.036
# 상권타입_관광특구        0.4003      0.479      0.836      0.403      -0.539       1.340
# 상권타입_발달상권        0.2322      0.094      2.475      0.013       0.048       0.416
# 상권타입_전통시장        0.0589      0.087      0.681      0.496      -0.111       0.229
# 개업율_요식업         -0.7842      0.209     -3.751      0.000      -1.194      -0.374
# 폐업율_요식업          0.5359      0.251      2.132      0.033       0.043       1.029
# 프랜차이즈비율_요식업      0.0346      0.042      0.828      0.408      -0.047       0.117
# 개업율_비요식업        -0.3814      0.576     -0.662      0.508      -1.512       0.750
# 폐업율_비요식업         0.0383      0.730      0.053      0.958      -1.393       1.469
# 프랜차이즈비율_비요식업     0.0561      0.197      0.285      0.776      -0.331       0.443
# 요식업비율           -0.1958      0.288     -0.679      0.497      -0.762       0.370
# ==============================================================================
# Omnibus:                        8.842   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):               12.186
# Skew:                          -0.011   Prob(JB):                      0.00226
# Kurtosis:                       3.475   Cond. No.                     5.77e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.77e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame({'variable' : col_i, 'VIF' : variance_inflation_factor(model_new.exog, i)} for i, col_i in enumerate(model_new.exog_names) if col_i != 'const')
vif[vif.VIF>4]
# Out:
# Empty DataFrame
# Columns: [variable, VIF]
# Index: []

# %% [markdown]
# ### Influence Plot

# %%
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(8,8))
sm.graphics.influence_plot(res, ax=ax, alpha=0.05, criterion='cooks')
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,8))
sm.graphics.qqplot(ax=ax, data=df['평균매매가'], line='45', label='평균매매가')
ax.legend()
plt.show()

# %% [markdown]
# ## GLM

# %% [markdown]
# ## Creating New Features

# %%
# # 매출건수당 매출금액(상권의 가격대 유추가능?)
# from copy import deepcopy

# X_add = deepcopy(X)
# X_add['건수당매출'] = X_add['매출액'] / X_add['매출건수']
# X_add = X_add.drop(['매출액', '매출건수'], axis=1)

# %%
# model_add = sm.OLS(endog=df['평균매매가'], exog=X_add, missing='drop')

# res_add = model_add.fit()
# # print(res_add.summary()) # Not significant Treatment

# %% [markdown]
# ## Feature Importance & Regression 종합
# Gradient Boosting Machine의

# %%
# load feature importance

df_imp = pd.read_csv('featureimportance.csv')
df_imp = df_imp.set_index('0')
df_imp.index.name = None
df_imp.columns = ['Feature_Importance']

# %%
df_res = df_imp.join([res_new.params[1:].rename('coef'),res_new.pvalues[1:].rename('p-values')])
df_res = df_res.sort_values(by='Feature_Importance', ascending=False)

# %%
df_res.round(4)
# Out:
#            Feature_Importance    coef  p-values
# 생활인구_야간비율              0.1905 -0.2265    0.0000
# 아파트_평균_시가              0.1685  0.2713    0.0000
# 112신고                  0.1235 -0.0065    0.7922
# Subway                 0.0698  0.1381    0.0000
# 개업율                    0.0521 -0.0272    0.3432
# 총_생활인구                 0.0498  0.0542    0.2181
# 생활인구_심야비율              0.0454 -0.0611    0.1723
# 프랜차이즈_침투율              0.0409 -0.0443    0.0970
# 매출액                    0.0398 -0.0019    0.9599
# 살인                     0.0376  0.0666    0.0001
# 도박                     0.0370 -0.0316    0.0540
# 생활인구_여성비율              0.0246  0.0325    0.2436
# 아파트_단지수                0.0230  0.0631    0.0732
# 폐업율                    0.0149  0.0119    0.6837
# 방화                     0.0125 -0.0361    0.0362
# 강도                     0.0119 -0.0383    0.0209
# Bus                    0.0117 -0.0768    0.0093
# 폭력                     0.0109  0.0119    0.6961
# 강간                     0.0087 -0.0288    0.3608
# 절도                     0.0077  0.0604    0.0592
# 마약                     0.0063  0.0191    0.2994
# 상권타입_골목상권              0.0052 -0.1541    0.1046
# 약취                     0.0048  0.0103    0.4596
# 상권타입_전통시장              0.0021 -0.1040    0.3200
# 상권타입_발달상권              0.0004  0.0016    0.9872
# 유흥업소                   0.0003  0.0144    0.5552
# 상권타입_관광특구              0.0000  0.2718    0.4209

# %%
# Feature Selection
df_res.loc[df_res['p-values']<0.1,:].round(4)
# Out:
#            Feature_Importance    coef  p-values
# 생활인구_야간비율              0.1905 -0.2265    0.0000
# 아파트_평균_시가              0.1685  0.2713    0.0000
# Subway                 0.0698  0.1381    0.0000
# 프랜차이즈_침투율              0.0409 -0.0443    0.0970
# 살인                     0.0376  0.0666    0.0001
# 도박                     0.0370 -0.0316    0.0540
# 아파트_단지수                0.0230  0.0631    0.0732
# 방화                     0.0125 -0.0361    0.0362
# 강도                     0.0119 -0.0383    0.0209
# Bus                    0.0117 -0.0768    0.0093
# 절도                     0.0077  0.0604    0.0592

# %% [markdown]
# Result : Bus, Subway, 유흥업소, 강간, 절도, 폭력, 방화, 약취, 112신고, 아파트_단지수, 아파트_평균_시가, 폐업율, 매출액, 상권타입
