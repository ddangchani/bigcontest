# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Linear Models
# with `Statsmodels` package

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# for korean plotting
plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

# Pandas option
pd.set_option('display.max_columns', None)

# %%
# data load
df = pd.read_csv('df_preprocessed.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1671 entries, 0 to 1670
# Data columns (total 40 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Bus             1671 non-null   float64
#  1   Subway          1671 non-null   float64
#  2   유흥업소            1671 non-null   float64
#  3   살인              1671 non-null   int64
#  4   강도              1671 non-null   int64
#  5   강간              1671 non-null   int64
#  6   절도              1671 non-null   int64
#  7   폭력              1671 non-null   int64
#  8   방화              1671 non-null   int64
#  9   마약              1671 non-null   int64
#  10  약취              1671 non-null   int64
#  11  도박              1671 non-null   int64
#  12  전체범죄            1671 non-null   int64
#  13  112신고           1671 non-null   float64
#  14  총_생활인구          1668 non-null   float64
#  15  남성_생활인구         1668 non-null   float64
#  16  여성_생활인구         1668 non-null   float64
#  17  연령대_10_생활인구     1668 non-null   float64
#  18  연령대_20_생활인구     1668 non-null   float64
#  19  연령대_30_생활인구     1668 non-null   float64
#  20  연령대_40_생활인구     1668 non-null   float64
#  21  연령대_50_생활인구     1668 non-null   float64
#  22  연령대_60_이상_생활인구  1668 non-null   float64
#  23  시간대_1_생활인구_수    1668 non-null   float64
#  24  시간대_2_생활인구_수    1668 non-null   float64
#  25  시간대_3_생활인구_수    1668 non-null   float64
#  26  시간대_4_생활인구_수    1668 non-null   float64
#  27  시간대_5_생활인구_수    1668 non-null   float64
#  28  시간대_6_생활인구_수    1668 non-null   float64
#  29  아파트_단지수         1486 non-null   float64
#  30  아파트_평균_시가       1486 non-null   float64
#  31  개업율             1665 non-null   float64
#  32  폐업율             1665 non-null   float64
#  33  프랜차이즈_침투율       1665 non-null   float64
#  34  매출액             1651 non-null   float64
#  35  매출건수            1651 non-null   float64
#  36  상권타입_골목상권       1671 non-null   int64
#  37  상권타입_관광특구       1671 non-null   int64
#  38  상권타입_발달상권       1671 non-null   int64
#  39  상권타입_전통시장       1671 non-null   int64
# dtypes: float64(26), int64(14)
# memory usage: 522.3 KB

# %%
# Ordered Categorical Variable
cols_crime = ['살인', '강도', '강간', '절도', '폭력', '방화', '마약', '약취', '도박', '전체범죄']

t = pd.CategoricalDtype(categories=[1,2,3,4,5], ordered=True)
df[cols_crime] = df[cols_crime].astype(t)

# %%
df.columns[~df.columns.str.contains('생활인구')]
# Out:
# Index(['Bus', 'Subway', '유흥업소', '살인', '강도', '강간', '절도', '폭력', '방화', '마약', '약취',
#        '도박', '전체범죄', '112신고', '아파트_단지수', '아파트_평균_시가', '개업율', '폐업율',
#        '프랜차이즈_침투율', '매출액', '매출건수', '상권타입_골목상권', '상권타입_관광특구', '상권타입_발달상권',
#        '상권타입_전통시장'],
#       dtype='object')

# %%
# Endog, Exog, add Constatnt
X = df[df.columns[~df.columns.str.contains('생활인구')]]
X = sm.add_constant(X, prepend=True)
y = df['총_생활인구']

# %% [markdown]
# ### OLS

# %%
# Model
model = sm.OLS(endog=y, exog=X, missing='drop')

# %%
# Result
res = model.fit()

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 총_생활인구   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.667
# Method:                 Least Squares   F-statistic:                     124.6
# Date:                Sat, 15 Oct 2022   Prob (F-statistic):               0.00
# Time:                        13:15:10   Log-Likelihood:                -1085.4
# No. Observations:                1481   AIC:                             2221.
# Df Residuals:                    1456   BIC:                             2353.
# Df Model:                          24
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0235      0.062     -0.377      0.706      -0.146       0.099
# Bus            0.1145      0.018      6.415      0.000       0.079       0.150
# Subway         0.1260      0.015      8.460      0.000       0.097       0.155
# 유흥업소           0.0595      0.015      4.061      0.000       0.031       0.088
# 살인            -0.0013      0.010     -0.128      0.898      -0.021       0.018
# 강도            -0.0095      0.010     -0.932      0.351      -0.029       0.010
# 강간            -0.0357      0.020     -1.785      0.075      -0.075       0.004
# 절도             0.0455      0.025      1.787      0.074      -0.004       0.095
# 폭력             0.0415      0.027      1.558      0.120      -0.011       0.094
# 방화             0.0177      0.010      1.693      0.091      -0.003       0.038
# 마약             0.0131      0.011      1.171      0.242      -0.009       0.035
# 약취            -0.0167      0.009     -1.948      0.052      -0.034       0.000
# 도박            -0.0010      0.010     -0.096      0.924      -0.021       0.019
# 전체범죄          -0.0034      0.041     -0.081      0.935      -0.084       0.078
# 112신고          0.0403      0.015      2.740      0.006       0.011       0.069
# 아파트_단지수        0.4445      0.017     26.411      0.000       0.412       0.478
# 아파트_평균_시가     -0.0229      0.015     -1.521      0.129      -0.053       0.007
# 개업율            0.0087      0.017      0.507      0.612      -0.025       0.042
# 폐업율            0.0381      0.017      2.183      0.029       0.004       0.072
# 프랜차이즈_침투율     -0.0451      0.017     -2.667      0.008      -0.078      -0.012
# 매출액            0.0575      0.044      1.297      0.195      -0.029       0.144
# 매출건수           0.2415      0.044      5.510      0.000       0.156       0.327
# 상권타입_골목상권      0.0640      0.058      1.098      0.273      -0.050       0.179
# 상권타입_관광특구      0.1059      0.209      0.507      0.612      -0.304       0.516
# 상권타입_발달상권      0.0074      0.060      0.124      0.901      -0.110       0.125
# 상권타입_전통시장     -0.2009      0.063     -3.175      0.002      -0.325      -0.077
# ==============================================================================
# Omnibus:                     1085.022   Durbin-Watson:                   1.899
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           100361.999
# Skew:                          -2.660   Prob(JB):                         0.00
# Kurtosis:                      42.976   Cond. No.                     5.64e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.53e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame({'variable' : col_i, 'VIF' : variance_inflation_factor(model.exog, i)} for i, col_i in enumerate(model.exog_names) if col_i != 'const')
vif
# Out:
# /Users/dangchan/miniforge3/envs/torch/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#      variable        VIF
# 0         Bus   1.696082
# 1      Subway   1.203912
# 2        유흥업소   1.302971
# 3          살인   1.353832
# 4          강도   1.392598
# 5          강간   5.082242
# 6          절도   8.304427
# 7          폭력   9.004269
# 8          방화   1.316199
# 9          마약   1.751470
# 10         약취   1.183565
# 11         도박   1.405416
# 12       전체범죄  20.956745
# 13      112신고   1.148493
# 14    아파트_단지수   1.611708
# 15  아파트_평균_시가   1.308763
# 16        개업율   1.327391
# 17        폐업율   1.358454
# 18  프랜차이즈_침투율   1.360089
# 19        매출액  10.200028
# 20       매출건수   9.886727
# 21  상권타입_골목상권        inf
# 22  상권타입_관광특구        inf
# 23  상권타입_발달상권        inf
# 24  상권타입_전통시장        inf

# %%
# 전체범죄 제외 필요, 매출액/매출건수 조정 필요
X_new = X.drop(['전체범죄', '매출건수'], axis=1)

# %%
# Model_new
model_new = sm.OLS(endog=y, exog=X_new, missing='drop')

res_new = model_new.fit()
print(res_new.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 총_생활인구   R-squared:                       0.666
# Model:                            OLS   Adj. R-squared:                  0.661
# Method:                 Least Squares   F-statistic:                     132.0
# Date:                Sat, 15 Oct 2022   Prob (F-statistic):               0.00
# Time:                        13:15:11   Log-Likelihood:                -1100.7
# No. Observations:                1481   AIC:                             2247.
# Df Residuals:                    1458   BIC:                             2369.
# Df Model:                          22
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0161      0.063     -0.256      0.798      -0.140       0.107
# Bus            0.1219      0.018      6.783      0.000       0.087       0.157
# Subway         0.1265      0.015      8.412      0.000       0.097       0.156
# 유흥업소           0.0608      0.015      4.107      0.000       0.032       0.090
# 살인         -3.235e-05      0.010     -0.003      0.997      -0.020       0.020
# 강도            -0.0090      0.010     -0.874      0.382      -0.029       0.011
# 강간            -0.0324      0.019     -1.666      0.096      -0.070       0.006
# 절도             0.0421      0.020      2.134      0.033       0.003       0.081
# 폭력             0.0374      0.019      1.999      0.046       0.001       0.074
# 방화             0.0188      0.011      1.781      0.075      -0.002       0.040
# 마약             0.0123      0.011      1.091      0.276      -0.010       0.034
# 약취            -0.0180      0.009     -2.102      0.036      -0.035      -0.001
# 도박            -0.0014      0.010     -0.141      0.888      -0.021       0.018
# 112신고          0.0404      0.015      2.718      0.007       0.011       0.069
# 아파트_단지수        0.4575      0.017     27.223      0.000       0.425       0.491
# 아파트_평균_시가     -0.0404      0.015     -2.716      0.007      -0.070      -0.011
# 개업율            0.0108      0.017      0.622      0.534      -0.023       0.045
# 폐업율            0.0406      0.018      2.306      0.021       0.006       0.075
# 프랜차이즈_침투율     -0.0169      0.016     -1.039      0.299      -0.049       0.015
# 매출액            0.2729      0.021     12.984      0.000       0.232       0.314
# 상권타입_골목상권      0.0585      0.059      0.993      0.321      -0.057       0.174
# 상권타입_관광특구      0.1127      0.211      0.535      0.593      -0.301       0.526
# 상권타입_발달상권      0.0007      0.061      0.011      0.991      -0.118       0.120
# 상권타입_전통시장     -0.1880      0.064     -2.945      0.003      -0.313      -0.063
# ==============================================================================
# Omnibus:                     1060.134   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            91276.909
# Skew:                          -2.582   Prob(JB):                         0.00
# Kurtosis:                      41.112   Cond. No.                     1.32e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.72e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# retest VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame({'variable' : col_i, 'VIF' : variance_inflation_factor(model_new.exog, i)} for i, col_i in enumerate(model_new.exog_names) if col_i != 'const')
vif ## VIF problem solved
# Out:
# /Users/dangchan/miniforge3/envs/torch/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#      variable       VIF
# 0         Bus  1.685262
# 1      Subway  1.203592
# 2        유흥업소  1.301997
# 3          살인  1.347281
# 4          강도  1.392470
# 5          강간  4.687108
# 6          절도  4.883500
# 7          폭력  4.337966
# 8          방화  1.315709
# 9          마약  1.750576
# 10         약취  1.159880
# 11         도박  1.391602
# 12      112신고  1.148488
# 13    아파트_단지수  1.576238
# 14  아파트_평균_시가  1.250690
# 15        개업율  1.325466
# 16        폐업율  1.357208
# 17  프랜차이즈_침투율  1.235442
# 18        매출액  2.252823
# 19  상권타입_골목상권       inf
# 20  상권타입_관광특구       inf
# 21  상권타입_발달상권       inf
# 22  상권타입_전통시장       inf

# %% [markdown]
# #### Target Variable changing

# %%
# endog = 남성/여성생활인구?
# Model_men
model_men = sm.OLS(endog=df['남성_생활인구'], exog=X_new, missing='drop')

res_men = model_men.fit()
print(res_men.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                남성_생활인구   R-squared:                       0.663
# Model:                            OLS   Adj. R-squared:                  0.658
# Method:                 Least Squares   F-statistic:                     130.5
# Date:                Sat, 15 Oct 2022   Prob (F-statistic):               0.00
# Time:                        13:15:11   Log-Likelihood:                -1110.0
# No. Observations:                1481   AIC:                             2266.
# Df Residuals:                    1458   BIC:                             2388.
# Df Model:                          22
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0234      0.063     -0.370      0.711      -0.148       0.101
# Bus            0.1180      0.018      6.530      0.000       0.083       0.153
# Subway         0.1318      0.015      8.710      0.000       0.102       0.161
# 유흥업소           0.0665      0.015      4.464      0.000       0.037       0.096
# 살인             0.0014      0.010      0.142      0.887      -0.019       0.021
# 강도            -0.0081      0.010     -0.780      0.435      -0.028       0.012
# 강간            -0.0342      0.020     -1.751      0.080      -0.073       0.004
# 절도             0.0403      0.020      2.032      0.042       0.001       0.079
# 폭력             0.0418      0.019      2.224      0.026       0.005       0.079
# 방화             0.0205      0.011      1.929      0.054      -0.000       0.041
# 마약             0.0095      0.011      0.840      0.401      -0.013       0.032
# 약취            -0.0170      0.009     -1.970      0.049      -0.034   -7.49e-05
# 도박            -0.0012      0.010     -0.121      0.903      -0.021       0.019
# 112신고          0.0454      0.015      3.036      0.002       0.016       0.075
# 아파트_단지수        0.4471      0.017     26.438      0.000       0.414       0.480
# 아파트_평균_시가     -0.0403      0.015     -2.690      0.007      -0.070      -0.011
# 개업율            0.0092      0.017      0.527      0.598      -0.025       0.043
# 폐업율            0.0365      0.018      2.059      0.040       0.002       0.071
# 프랜차이즈_침투율     -0.0220      0.016     -1.347      0.178      -0.054       0.010
# 매출액            0.2789      0.021     13.187      0.000       0.237       0.320
# 상권타입_골목상권      0.0557      0.059      0.941      0.347      -0.060       0.172
# 상권타입_관광특구      0.1251      0.212      0.590      0.555      -0.291       0.541
# 상권타입_발달상권      0.0082      0.061      0.135      0.893      -0.111       0.128
# 상권타입_전통시장     -0.2125      0.064     -3.308      0.001      -0.339      -0.087
# ==============================================================================
# Omnibus:                     1071.565   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            95535.000
# Skew:                          -2.617   Prob(JB):                         0.00
# Kurtosis:                      41.997   Cond. No.                     1.32e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.72e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Model_women
model_women = sm.OLS(endog=df['여성_생활인구'], exog=X_new, missing='drop')

res_women = model_women.fit()
print(res_women.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                여성_생활인구   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.659
# Method:                 Least Squares   F-statistic:                     131.1
# Date:                Sat, 15 Oct 2022   Prob (F-statistic):               0.00
# Time:                        13:15:12   Log-Likelihood:                -1100.0
# No. Observations:                1481   AIC:                             2246.
# Df Residuals:                    1458   BIC:                             2368.
# Df Model:                          22
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0089      0.063     -0.141      0.888      -0.132       0.115
# Bus            0.1249      0.018      6.958      0.000       0.090       0.160
# Subway         0.1210      0.015      8.047      0.000       0.091       0.150
# 유흥업소           0.0552      0.015      3.734      0.000       0.026       0.084
# 살인            -0.0013      0.010     -0.127      0.899      -0.021       0.019
# 강도            -0.0096      0.010     -0.934      0.351      -0.030       0.011
# 강간            -0.0312      0.019     -1.605      0.109      -0.069       0.007
# 절도             0.0434      0.020      2.200      0.028       0.005       0.082
# 폭력             0.0335      0.019      1.793      0.073      -0.003       0.070
# 방화             0.0173      0.011      1.638      0.102      -0.003       0.038
# 마약             0.0150      0.011      1.331      0.183      -0.007       0.037
# 약취            -0.0191      0.009     -2.229      0.026      -0.036      -0.002
# 도박            -0.0015      0.010     -0.146      0.884      -0.021       0.018
# 112신고          0.0364      0.015      2.451      0.014       0.007       0.065
# 아파트_단지수        0.4659      0.017     27.732      0.000       0.433       0.499
# 아파트_평균_시가     -0.0402      0.015     -2.701      0.007      -0.069      -0.011
# 개업율            0.0126      0.017      0.729      0.466      -0.021       0.047
# 폐업율            0.0442      0.018      2.515      0.012       0.010       0.079
# 프랜차이즈_침투율     -0.0122      0.016     -0.748      0.455      -0.044       0.020
# 매출액            0.2652      0.021     12.626      0.000       0.224       0.306
# 상권타입_골목상권      0.0601      0.059      1.022      0.307      -0.055       0.176
# 상권타입_관광특구      0.1025      0.211      0.486      0.627      -0.311       0.516
# 상권타입_발달상권     -0.0068      0.061     -0.112      0.911      -0.126       0.112
# 상권타입_전통시장     -0.1648      0.064     -2.582      0.010      -0.290      -0.040
# ==============================================================================
# Omnibus:                     1067.513   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            93006.834
# Skew:                          -2.608   Prob(JB):                         0.00
# Kurtosis:                      41.471   Cond. No.                     1.32e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.72e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Creating New Features

# %%
# 매출건수당 매출금액(상권의 가격대 유추가능?)
from copy import deepcopy

X_add = deepcopy(X_new)
X_add['건수당매출'] = X_add['매출액'] / X_add['매출건수']
X_add = X_add.drop(['매출액', '매출건수'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/torch/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/miniforge3/envs/torch/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniforge3/envs/torch/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '매출건수'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/dangchan/Desktop/Github/Bigcontest/analysis.ipynb 셀 21 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/dangchan/Desktop/Github/Bigcontest/analysis.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> from copy import deepcopy
#       <a href='vscode-notebook-cell:/Users/dangchan/Desktop/Github/Bigcontest/analysis.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> X_add = deepcopy(X_new)
# ----> <a href='vscode-notebook-cell:/Users/dangchan/Desktop/Github/Bigcontest/analysis.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> X_add['건수당매출'] = X_add['매출액'] / X_add['매출건수']
#       <a href='vscode-notebook-cell:/Users/dangchan/Desktop/Github/Bigcontest/analysis.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a> X_add = X_add.drop(['매출액', '매출건수'], axis=1)
#
# File ~/miniforge3/envs/torch/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/miniforge3/envs/torch/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: '매출건수'

# %%
model_add = sm.OLS(endog=df['총_생활인구'], exog=X_add, missing='drop')

res_add = model_add.fit()
print(res_add.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 총_생활인구   R-squared:                       0.572
# Model:                            OLS   Adj. R-squared:                  0.566
# Method:                 Least Squares   F-statistic:                     88.75
# Date:                Fri, 14 Oct 2022   Prob (F-statistic):          4.44e-250
# Time:                        13:33:46   Log-Likelihood:                -1488.0
# No. Observations:                1481   AIC:                             3022.
# Df Residuals:                    1458   BIC:                             3144.
# Df Model:                          22
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.3818      0.423     -5.634      0.000      -3.211      -1.553
# Bus            0.3220      0.031     10.321      0.000       0.261       0.383
# Subway         0.2404      0.034      7.164      0.000       0.175       0.306
# 유흥업소           0.3419      0.029     11.607      0.000       0.284       0.400
# 살인            -0.0193      0.013     -1.467      0.143      -0.045       0.007
# 강도             0.0030      0.013      0.223      0.824      -0.023       0.029
# 강간            -0.0041      0.025     -0.164      0.870      -0.054       0.045
# 절도             0.0569      0.026      2.220      0.027       0.007       0.107
# 폭력            -0.0053      0.024     -0.220      0.826      -0.053       0.042
# 방화             0.0194      0.014      1.417      0.157      -0.007       0.046
# 마약            -0.0029      0.015     -0.196      0.845      -0.032       0.026
# 약취            -0.0107      0.011     -0.959      0.338      -0.032       0.011
# 도박             0.0079      0.013      0.600      0.549      -0.018       0.034
# 112신고          0.2066      0.045      4.633      0.000       0.119       0.294
# 아파트_단지수        0.4806      0.020     24.391      0.000       0.442       0.519
# 아파트_평균_시가     -0.0021      0.019     -0.115      0.909      -0.039       0.034
# 개업율            0.0072      0.023      0.313      0.754      -0.038       0.053
# 폐업율            0.0601      0.024      2.535      0.011       0.014       0.107
# 프랜차이즈_침투율     -0.0309      0.023     -1.356      0.175      -0.076       0.014
# 상권타입_골목상권     -1.0664      0.125     -8.518      0.000      -1.312      -0.821
# 상권타입_관광특구      0.6213      0.293      2.122      0.034       0.047       1.196
# 상권타입_발달상권     -0.7995      0.133     -6.024      0.000      -1.060      -0.539
# 상권타입_전통시장     -1.1372      0.130     -8.747      0.000      -1.392      -0.882
# 건수당매출          0.0007      0.001      0.819      0.413      -0.001       0.002
# ==============================================================================
# Omnibus:                      714.129   Durbin-Watson:                   1.846
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7274.595
# Skew:                           1.998   Prob(JB):                         0.00
# Kurtosis:                      13.096   Cond. No.                     3.36e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.61e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### 시간대별 생활인구 as Target Variable
# 시간대 1부터 6까지 각각 00~06시, 06~11시, 11~14시, 14~17시, 17~21시, 21~24시

# %%
# 시간대별 생활인구?
# 심야시간대
model_time_6 = sm.OLS(endog=df['시간대_6_생활인구_수'], exog=X_new, missing='drop')

res_time_6 = model_time_6.fit()
print(res_time_6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           시간대_6_생활인구_수   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.654
# Method:                 Least Squares   F-statistic:                     128.1
# Date:                Sat, 15 Oct 2022   Prob (F-statistic):          3.94e-321
# Time:                        09:18:10   Log-Likelihood:                -1082.7
# No. Observations:                1481   AIC:                             2211.
# Df Residuals:                    1458   BIC:                             2333.
# Df Model:                          22
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0089      0.062     -0.142      0.887      -0.131       0.113
# Bus            0.1246      0.018      7.024      0.000       0.090       0.159
# Subway         0.1043      0.015      7.020      0.000       0.075       0.133
# 유흥업소           0.0585      0.015      4.000      0.000       0.030       0.087
# 살인             0.0016      0.010      0.160      0.873      -0.018       0.021
# 강도            -0.0079      0.010     -0.783      0.434      -0.028       0.012
# 강간            -0.0396      0.019     -2.066      0.039      -0.077      -0.002
# 절도             0.0467      0.019      2.397      0.017       0.008       0.085
# 폭력             0.0324      0.018      1.756      0.079      -0.004       0.069
# 방화             0.0170      0.010      1.629      0.104      -0.003       0.038
# 마약             0.0169      0.011      1.525      0.128      -0.005       0.039
# 약취            -0.0174      0.008     -2.060      0.040      -0.034      -0.001
# 도박             0.0009      0.010      0.090      0.928      -0.019       0.021
# 112신고          0.0528      0.015      3.596      0.000       0.024       0.082
# 아파트_단지수        0.4722      0.017     28.438      0.000       0.440       0.505
# 아파트_평균_시가     -0.0617      0.015     -4.193      0.000      -0.091      -0.033
# 개업율            0.0092      0.017      0.538      0.591      -0.024       0.043
# 폐업율            0.0478      0.017      2.748      0.006       0.014       0.082
# 프랜차이즈_침투율     -0.0098      0.016     -0.611      0.541      -0.041       0.022
# 매출액            0.2311      0.021     11.130      0.000       0.190       0.272
# 상권타입_골목상권      0.0602      0.058      1.034      0.301      -0.054       0.174
# 상권타입_관광특구      0.1096      0.208      0.526      0.599      -0.299       0.518
# 상권타입_발달상권     -0.0495      0.060     -0.827      0.409      -0.167       0.068
# 상권타입_전통시장     -0.1291      0.063     -2.047      0.041      -0.253      -0.005
# ==============================================================================
# Omnibus:                     1156.329   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           124961.746
# Skew:                          -2.906   Prob(JB):                         0.00
# Kurtosis:                      47.623   Cond. No.                     1.32e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.72e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Feature Importance & Regression 종합
# Gradient Boosting Machine의

# %%
# load feature importance

df_imp = pd.read_csv('featureimportance.csv')
df_imp = df_imp.set_index('0')
df_imp.index.name = None
df_imp.columns = ['Feature_Importance']

# %%
df_res = df_imp.join([res_new.params[1:].rename('coef'),res_new.pvalues[1:].rename('p-values')])
df_res = df_res.sort_values(by='Feature_Importance', ascending=False)

# %%
df_res.round(4)
# Out:
#            Feature_Importance    coef  p-values
# 아파트_단지수                0.5720  0.4575    0.0000
# 매출액                    0.1686  0.2729    0.0000
# 프랜차이즈_침투율              0.0356 -0.0169    0.2990
# 아파트_평균_시가              0.0346 -0.0404    0.0067
# 폐업율                    0.0321  0.0406    0.0213
# 112신고                  0.0290  0.0404    0.0067
# 개업율                    0.0269  0.0108    0.5340
# Bus                    0.0248  0.1219    0.0000
# 유흥업소                   0.0212  0.0608    0.0000
# Subway                 0.0200  0.1265    0.0000
# 상권타입_전통시장              0.0093 -0.1880    0.0033
# 폭력                     0.0065  0.0374    0.0458
# 절도                     0.0048  0.0421    0.0330
# 상권타입_골목상권              0.0045  0.0585    0.3206
# 방화                     0.0042  0.0188    0.0751
# 마약                     0.0018  0.0123    0.2757
# 강간                     0.0010 -0.0324    0.0959
# 강도                     0.0009 -0.0090    0.3822
# 도박                     0.0009 -0.0014    0.8876
# 약취                     0.0008 -0.0180    0.0357
# 살인                     0.0007 -0.0000    0.9974
# 상권타입_발달상권              0.0000  0.0007    0.9911
# 상권타입_관광특구              0.0000  0.1127    0.5929

# %%
# Feature Selection
df_res.loc[df_res['p-values']<0.1,:]
# Out:
#            Feature_Importance      coef       p-values
# 아파트_단지수              0.572046  0.457537  2.731397e-132
# 매출액                  0.168585  0.272852   1.472742e-36
# 아파트_평균_시가            0.034599 -0.040427   6.695490e-03
# 폐업율                  0.032058  0.040585   2.125167e-02
# 112신고                0.029027  0.040352   6.655427e-03
# Bus                  0.024823  0.121853   1.700083e-11
# 유흥업소                 0.021155  0.060760   4.237058e-05
# Subway               0.020020  0.126518   9.442545e-17
# 상권타입_전통시장            0.009269 -0.187991   3.283190e-03
# 폭력                   0.006507  0.037353   4.583644e-02
# 절도                   0.004839  0.042097   3.297435e-02
# 방화                   0.004243  0.018839   7.505994e-02
# 강간                   0.000992 -0.032355   9.588679e-02
# 약취                   0.000766 -0.018009   3.571117e-02

# %% [markdown]
# Result : Bus, Subway, 유흥업소, 강간, 절도, 폭력, 방화, 약취, 112신고, 아파트_단지수, 아파트_평균_시가, 폐업율, 매출액, 상권타입
